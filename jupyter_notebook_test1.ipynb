# %%
import numpy as np
import matplotlib as plt

print("Hello world!")
# Out:
# Hello world!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       2 import matplotlib as plt
#       4 print("Hello world!")
# ----> 5 help(colormaps)
#
# NameError: name 'colormaps' is not defined

# %%
import matplotlib.pyplot as plt

x = [2,6,7,7.5,8,14]
y = [4,12,14,15,16,28]


plt.axes((0,0,1,1),facecolor="yellow")
plt.axis([0,15,0,30])
plt.title("x vs y")
plt.plot(x,y)
plt.show()
